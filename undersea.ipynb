# %%
# !underthesea list-data
# Out:
# | Name                | Type        | License | Year | Directory                    |
# |---------------------+-------------+---------+------+------------------------------|
# | UIT_ABSA_RESTAURANT | Sentiment   | Open    | 2021 | datasets/UIT_ABSA_RESTAURANT |
# | UIT_ABSA_HOTEL      | Sentiment   | Open    | 2021 | datasets/UIT_ABSA_HOTEL      |
# | SE_Vietnamese-UBS   | Sentiment   | Open    | 2020 | datasets/SE_Vietnamese-UBS   |
# | CP_Vietnamese-UNC   | Plaintext   | Open    | 2020 | datasets/CP_Vietnamese-UNC   |
# | DI_Vietnamese-UVD   | Dictionary  | Open    | 2020 | datasets/DI_Vietnamese-UVD   |
# | UTS2017-BANK        | Categorized | Open    | 2017 | datasets/UTS2017-BANK        |
# | VNTQ_SMALL          | Plaintext   | Open    | 2012 | datasets/LTA                 |
# | VNTQ_BIG            | Plaintext   | Open    | 2012 | datasets/LTA                 |
# | VNESES              | Plaintext   | Open    | 2012 | datasets/LTA                 |
# ...

# %%
# !underthesea list-model
# Out:
# | Name            | Type           | License | Year | Directory              |
# |-----------------+----------------+---------+------+------------------------|
# | TC_BANK_V131    | Sentiment      | Open    | 2021 | models\TC_BANK_V131    |
# | TC_GENERAL_V131 | Classification | Open    | 2019 | models\TC_GENERAL_V131 |
# | TC_BANK         | Classification | Open    | 2019 | models\TC_BANK         |
# | SA_GENERAL      | Sentiment      | Open    | 2019 | models\SA_GENERAL      |
# | SA_GENERAL_V131 | Sentiment      | Open    | 2021 | models\SA_GENERAL_V131 |
# | SA_BANK         | Sentiment      | Open    | 2019 | models\SA_BANK         |
# | SA_BANK_V131    | Sentiment      | Open    | 2021 | models\SA_BANK_V131    |

# %%
# !pip install Cython
# Out:
# ...
#   Using cached Cython-0.29.26-py2.py3-none-any.whl (983 kB)
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'd:\zzz program_files\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install future scipy numpy scikit-learn
# !pip install -U fasttext --no-cache-dir --no-deps --force-reinstall
# Out:
# ...
# Using legacy 'setup.py install' for future, since package 'wheel' is not installed.
# ...
#     Running setup.py install for future: started
#     Running setup.py install for future: finished with status 'done'
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'd:\zzz program_files\python39\python.exe -m pip install --upgrade pip' command.
# ...
# Using legacy 'setup.py install' for fasttext, since package 'wheel' is not installed.
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'd:\zzz program_files\python39\python.exe -m pip install --upgrade pip' command.
#     Running setup.py install for fasttext: started
#     Running setup.py install for fasttext: finished with status 'done'
# ...

# %%
 # !pip install future scipy numpy scikit-learn==0.19.2 joblib
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'd:\zzz program_files\python39\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Hendrichs\\AppData\\Local\\Temp\\pip-install-v9a0mnxx\\scikit-learn\\setup.py'"'"'; __file__='"'"'C:\\Users\\Hendrichs\\AppData\\Local\\Temp\\pip-install-v9a0mnxx\\scikit-learn\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Hendrichs\AppData\Local\Temp\pip-record-zvmkuxgf\install-record.txt' --single-version-externally-managed --compile --install-headers 'd:\zzz program_files\python39\Include\scikit-learn'
#          cwd: C:\Users\Hendrichs\AppData\Local\Temp\pip-install-v9a0mnxx\scikit-learn\
#     Complete output (788 lines):
#     Partial import of sklearn during the build process.
#     INFO: blas_opt_info:
#     INFO: blas_armpl_info:
# ...

# %%
# -*- coding: utf-8 -*-

from underthesea import sent_tokenize , word_tokenize, pos_tag, chunk

text = "Cho hình vuông ABCD có AC= 10CM. Tính diện tích hình vuông"

# %%
sent_tokenize(text)
# Out:
# ['Cho hình vuông ABCD có AC= 10CM.', 'Tính diện tích hình vuông']

# %%
pos_tag(text)
# Out:
# [('Cho', 'E'),
#  ('hình vuông', 'N'),
#  ('ABCD', 'Np'),
#  ('có', 'V'),
#  ('AC = 10CM', 'N'),
#  ('. Tính', 'V'),
#  ('diện tích', 'N'),
#  ('hình vuông', 'M')]
